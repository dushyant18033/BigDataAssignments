# %%
hdfs_e1 = [22.509477397328745, 251.862155380873476, 44.75394942582140, 150.540043388599092, 4.95314047859909, 3.1987861174369, 16.4950235980529, 20.912178345980529]
hdfs_e2 = [21.773667732874554, 249.58760873476663, 43.515235821406044, 148.13695859909058, 4.853235165278117, 2.98285174369812, 15.053032159805298, 19.114360014597576]

# %%
pg_e1_b = [0.8241069793701172, 0.1673967123031616, 0.26167662143707277, 0.21938045024871827, 0.1610717296600342, 0.290036678314209, 0.16273510456085205, 0.16629159450531006]
pg_e2_b = [0.36961138248443604, 0.13508906364440917, 0.2291285753250122, 0.2173015832901001, 0.2394742488861084, 0.16658904552459716, 0.15846605300903321, 0.30710530281066895]

pg_e1_f = [11.372584899266561, 287.56904260317486, 121.9718411763509, 202.72570045789084, 4.612216234207153, 2.820171038309733, 5.820555051167806, 9.393634875615438]
pg_e2_f = [4.305006821950276, 234.6917590300242, 134.63548787434897, 321.71466700236004, 10.84055725733439, 4.718230565388997, 14.864173173904419, 18.67643944422404]

# %%
mdb_e1_b = [0.5248032331466674, 0.36573240756988523, 0.37603073120117186, 0.650059700012207, 0.2722919464111328, 0.18742387294769286, 0.943103289604187, 0.23130388259887696]
mdb_e2_b = [0.5436521053314209, 0.38195674419403075, 0.378934907913208, 0.6992531299591065, 0.2596954107284546, 0.1775022029876709, 0.859039044380188, 0.20791006088256836]

mdb_e1_f = [14.948185364405314, 303.7211236159007, 114.44110067685445, 206.15040723482767, 1.5650041898091633, 1.6539669036865234, 3.59218692779541, 2.78354541460673]
mdb_e2_f = [10.347276290257772, 256.56013584136963, 127.79095546404521, 329.0319859981537, 9.485195398330688, 5.4332239627838135, 40.85181665420532, 9.593047300974527]

# %%
Query = ["1.a","1.b","2.","3.","4.","5.","6.","7."]

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(Query,hdfs_e1,label='Executors=1')
plt.plot(Query,hdfs_e2,label='Executors=2')
plt.xlabel("Query")
plt.ylabel("Time in Seconds")
plt.legend()
plt.suptitle("Hadoop DFS Frontend")
plt.show()

# %%
plt.plot(Query,pg_e1_b,label='Executors=1')
plt.plot(Query,pg_e2_b,label='Executors=2')
plt.xlabel("Query")
plt.ylabel("Time in Seconds")
plt.legend()
plt.suptitle("PostgreSQL Backend")
plt.show()

# %%
plt.plot(Query,pg_e1_f,label='Executors=1')
plt.plot(Query,pg_e2_f,label='Executors=2')
plt.xlabel("Query")
plt.ylabel("Time in Seconds")
plt.legend()
plt.suptitle("PostgreSQL Frontend")
plt.show()

# %%
plt.plot(Query,mdb_e1_b,label='Executors=1')
plt.plot(Query,mdb_e2_b,label='Executors=2')
plt.xlabel("Query")
plt.ylabel("Time in Seconds")
plt.legend()
plt.suptitle("MongoDB Backend")
plt.show()

# %%
plt.plot(Query,mdb_e1_f,label='Executors=1')
plt.plot(Query,mdb_e2_f,label='Executors=2')
plt.xlabel("Query")
plt.ylabel("Time in Seconds")
plt.legend()
plt.suptitle("MongoDB Frontend")
plt.show()
